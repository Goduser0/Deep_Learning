# %% [markdown]
# >* ***算法的泛化误差***为：
# >$$\mathbb E(f;D)=bias^2(\boldsymbol x)+var(\boldsymbol x)+\varepsilon^2$$
# >也就是说泛化误差可分解为偏差、方差和噪声，噪声无法人为控制，所以通常认为：
# >$$\mathbb E(f;D)=bias^2(\boldsymbol x)+var(\boldsymbol x)$$
#
# >我们需要在模型复杂度之间权衡，使偏差和方差得以均衡（trade-off），才能使得模型的整体误差最小
# >![image.png](attachment:image.png)
